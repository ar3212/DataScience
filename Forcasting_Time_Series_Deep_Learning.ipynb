# %% [markdown]
# <a href="https://colab.research.google.com/github/zar7364/DataScience/blob/main/Forcasting_Time_Series_Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
import matplotlib.pyplot as plt

# %%
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
df=("/content/drive/MyDrive/Colab Notebooks/Forcast Deep Learning/monthly-beer-production-in-austr.csv")

# %%
#1. Load the Dataset
data=pd.read_csv(df)
data.head()
# Out:
#      Month  Monthly beer production
# 0  1956-01                     93.2
# 1  1956-02                     96.0
# 2  1956-03                     95.2
# 3  1956-04                     77.1
# 4  1956-05                     70.9

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 476 entries, 0 to 475
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Month                    476 non-null    object
#  1   Monthly beer production  476 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 7.6+ KB

# %%
data.describe().T
# Out:
#                          count        mean        std  ...     50%      75%    max
# Monthly beer production  476.0  136.395378  33.738725  ...  139.15  158.825  217.8
#
# [1 rows x 8 columns]

# %%
data.isna().sum()
# Out:
# Month                      0
# Monthly beer production    0
# dtype: int64

# %%
data.Month=data.set_index("Month")

# %%
data.index.freq = 'MS'

# %%
plt.figure(figsize=(24,9))
plt.plot(data.index, data["Monthly beer production"], linestyle="-")
plt.xlabel=('Dates')
plt.ylabel=('Total Production')
plt.show();
